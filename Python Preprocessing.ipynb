# %% [markdown]
# #  Preprocessing in python

# %% [markdown]
# ###  Loading libraries

# %%
import pandas as pd # handling dataframes
import numpy as np # array operations

# %%
import os

# %% [markdown]
# ### List the files in directory

# %%
for i in os.listdir("."):
    print(i)
# Out:
# .ipynb_checkpoints
# 692ee7e0c63fb2212bfe4a62a39ce71ee9b16fb3.torrent
# college-salaries
# college-salaries.zip
# postscndryunivsrvy2013dirinfo.csv
# Untitled.ipynb
# Untitled1.ipynb
# video-game-sales-with-ratings
# video-game-sales-with-ratings.zip

# %% [markdown]
# ### Change directory

# %%
os.chdir(os.getcwd()+"\\video-game-sales-with-ratings")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-79dc03cde23d> in <module>()
# ----> 1 os.chdir(os.getcwd()+"\\video-game-sales-with-ratings")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'D:\\Chaithanyas\\Material\\Python Tutorial\\Preprocessing task\\video-game-sales-with-ratings\\video-game-sales-with-ratings'

# %%
for i in os.listdir("."):print(i)
# Out:
# Video_Games_Sales_as_at_22_Dec_2016.csv

# %% [markdown]
# ###  Load Dataset

# %%
videogames = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv",header='infer')

# %% [markdown]
# ## EDA

# %%
videogames.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# ##### Data types

# %%
videogames.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %% [markdown]
# ##### Descriptive statistics

# %%
videogames.describe(include='all')
# Out:
#                                Name Platform  Year_of_Release   Genre  \
# count                         16717    16719     16450.000000   16717
# unique                        11562       31              NaN      12
# top     Need for Speed: Most Wanted      PS2              NaN  Action
# freq                             12     2161              NaN    3370
# mean                            NaN      NaN      2006.487356     NaN
# std                             NaN      NaN         5.878995     NaN
# min                             NaN      NaN      1980.000000     NaN
# 25%                             NaN      NaN      2003.000000     NaN
# 50%                             NaN      NaN      2007.000000     NaN
# 75%                             NaN      NaN      2010.000000     NaN
# max                             NaN      NaN      2020.000000     NaN
#
#               Publisher      NA_Sales      EU_Sales      JP_Sales  \
# ...
